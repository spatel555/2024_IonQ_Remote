# %% [markdown]
# ## import libraries

# %%
import matplotlib.pyplot as plt

# %%
v1p1 = {'4': 0.005,
 '7': 0.005,
 '9': 0.03,
 '10': 0.005,
 '11': 0.03,
 '12': 0.03,
 '13': 0.05,
 '14': 0.03,
 '15': 0.015,
 '16': 0.005,
 '17': 0.015,
 '18': 0.01,
 '19': 0.025,
 '20': 0.02,
 '21': 0.03,
 '22': 0.025,
 '33': 0.005,
 '35': 0.01,
 '36': 0.005,
 '37': 0.01,
 '39': 0.005,
 '41': 0.025,
 '42': 0.025,
 '43': 0.05,
 '44': 0.01,
 '45': 0.035,
 '46': 0.06,
 '47': 0.035,
 '48': 0.005,
 '49': 0.03,
 '50': 0.005,
 '51': 0.045,
 '52': 0.015,
 '53': 0.05,
 '54': 0.035,
 '57': 0.015,
 '58': 0.025,
 '59': 0.04,
 '60': 0.025,
 '61': 0.04,
 '62': 0.035,
 '63': 0.03}

plt.bar(v1p1.keys(), v1p1.values(), width=1, color='g')
# plt.hist(v9p1_output, wid)
# Out:
# <BarContainer object of 42 artists>

# %%
v9p1 = {'0': 0.105, '1': 0.205, '2': 0.025, '3': 0.665}

plt.bar(v9p1.keys(), v9p1.values(), width=0.5, color='g')
# plt.hist(v9p1_output, wid)
# Out:
# <BarContainer object of 4 artists>

# %%
v5p1 = {'0': 0.25, '1': 0.22, '2': 0.32, '3': 0.21}
plt.bar(v5p1.keys(), v5p1.values(), width=0.5, color='g')
# Out:
# <BarContainer object of 4 artists>

# %%
v2p1 = {'0': 0.01,
 '2': 0.05,
 '3': 0.01,
 '4': 0.005,
 '5': 0.05,
 '6': 0.015,
 '7': 0.015,
 '8': 0.005,
 '9': 0.015,
 '10': 0.015,
 '11': 0.015,
 '12': 0.045,
 '13': 0.01,
 '14': 0.03,
 '15': 0.015,
 '16': 0.025,
 '17': 0.005,
 '18': 0.01,
 '19': 0.015,
 '20': 0.005,
 '22': 0.005,
 '23': 0.005,
 '25': 0.005,
 '26': 0.02,
 '27': 0.015,
 '28': 0.01,
 '29': 0.01,
 '30': 0.015,
 '32': 0.015,
 '34': 0.01,
 '37': 0.025,
 '38': 0.015,
 '39': 0.03,
 '40': 0.005,
 '41': 0.055,
 '42': 0.035,
 '44': 0.035,
 '45': 0.04,
 '46': 0.075,
 '48': 0.04,
 '49': 0.005,
 '50': 0.02,
 '54': 0.015,
 '57': 0.015,
 '58': 0.01,
 '60': 0.015,
 '61': 0.04,
 '62': 0.045,
 '63': 0.005}

plt.bar(v2p1.keys(), v2p1.values(), width=0.5, color='g')
# Out:
# <BarContainer object of 49 artists>
